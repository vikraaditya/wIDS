# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv('train_wids.csv')
warnings.filterwarnings("ignore")

# %% [markdown]
# #### My functions

# %%
def splitcategories(df):
    nums=df._get_numeric_data().columns
    cats=list(set(df.columns)-set(nums))
    return nums,cats

def filterColsbyNA(df,num):
    df.shape
    temp=pd.DataFrame(df.isna().sum()).reset_index()
    temp=temp.set_axis(['name','nullcount'],axis=1)
    temp['ratio']=temp.nullcount/df.shape[0]*100
    return temp.loc[temp.ratio>num].name.to_list()

def getsmallercols(df,limit):
    nums=df._get_numeric_data().columns.to_list()
    a=[]
    for col in nums:
        if df[col].value_counts().count() < limit:
            a.append(col)
    return a
def addBinnedCols(df,cols,binSize):
    y=list(map(lambda x:x/binSize ,list(range(1,binSize+1)))) 
    for col in cols:
        a=df[col].quantile(y).to_list()
        df[str(col)+'_binned']=df[col].apply(lambda x:getVal(a,x))
    return df

# %% [markdown]
# ## Data Cleaning

# %%
cols=df.columns.to_list()
nums,cats=splitcategories(df)
nacols=filterColsbyNA(df,10)

# %%
nacols
# Out:
# ['energy_star_rating',
#  'direction_max_wind_speed',
#  'direction_peak_wind_speed',
#  'max_wind_speed',
#  'days_with_fog']

# %%
df[set(cols)-set(nacols)].isna().sum()
# Out:
# june_max_temp              0
# heating_degree_days        0
# days_above_100F            0
# days_above_110F            0
# september_min_temp         0
# cooling_degree_days        0
# precipitation_inches       0
# december_min_temp          0
# may_min_temp               0
# id                         0
# days_below_20F             0
# december_avg_temp          0
# february_min_temp          0
# september_avg_temp         0
# october_max_temp           0
# november_avg_temp          0
# january_min_temp           0
# floor_area                 0
# ELEVATION                  0
# june_avg_temp              0
# august_max_temp            0
# october_avg_temp           0
# july_avg_temp              0
# march_avg_temp             0
# october_min_temp           0
# days_below_0F              0
# november_min_temp          0
# snowfall_inches            0
# days_above_90F             0
# year_built              1837
# avg_temp                   0
# may_avg_temp               0
# november_max_temp          0
# snowdepth_inches           0
# may_max_temp               0
# january_avg_temp           0
# days_below_10F             0
# State_Factor               0
# january_max_temp           0
# february_avg_temp          0
# days_below_30F             0
# september_max_temp         0
# february_max_temp          0
# july_max_temp              0
# Year_Factor                0
# march_min_temp             0
# december_max_temp          0
# facility_type              0
# june_min_temp              0
# days_above_80F             0
# august_avg_temp            0
# building_class             0
# april_avg_temp             0
# april_min_temp             0
# july_min_temp              0
# march_max_temp             0
# april_max_temp             0
# august_min_temp            0
# site_eui                   0
# dtype: int64

# %%
#Dropping NA values of 1837 from year_built
df1=df.loc[~df[set(cols)-set(nacols)].year_built.isna()]
# Target Variable is site_eui

# %%
sns.boxplot(y=df1.site_eui)
# Out:
# <AxesSubplot:ylabel='site_eui'>

# %% [markdown]
# #### As we can see that there are too many outliers in dependent variable,hence trimming by 93rd percentile

# %%
lower,upper=df1.site_eui.quantile([0,0.939])

# %%
df2=df1.loc[(df1.site_eui>lower) & (df1.site_eui<upper)]
sns.boxplot(y=df2.site_eui)
# Out:
# <AxesSubplot:ylabel='site_eui'>

# %% [markdown]
# #### Plot dependent variable after removing outliers

# %%
red=round((df2.shape[0]/df.shape[0])*100,2)
print("Total reduction in dataset size after Data Cleaning %f "%(100- red)+"%")
df2=df2[set(cols)-set(nacols)]
df2
# Out:
# Total reduction in dataset size after Data Cleaning 8.380000 %
#        june_max_temp  heating_degree_days  days_above_100F  days_above_110F  \
# 1                 90                 2960                0                0
# 2                 90                 2960                0                0
# 3                 90                 2960                0                0
# 4                 90                 2960                0                0
# 5                 90                 2960                0                0
# ...              ...                  ...              ...              ...
# 75751             91                 3772                0                0
# 75752             91                 3772                0                0
# 75753             91                 3772                0                0
# 75754             86                 6218                0                0
# 75756             90                 5853                0                0
#
#        september_min_temp  cooling_degree_days  precipitation_inches  \
# 1                      52                  115                 16.59
# 2                      52                  115                 16.59
# 3                      52                  115                 16.59
# 4                      52                  115                 16.59
# 5                      52                  115                 16.59
# ...                   ...                  ...                   ...
# 75751                  44                  260                 45.03
# 75752                  44                  260                 45.03
# 75753                  44                  260                 45.03
# 75754                  41                   55                106.32
# 75756                  43                  148                107.69
#
#        december_min_temp  may_min_temp     id  ...  days_above_80F  \
# 1                     36            46      1  ...              14
# 2                     36            46      2  ...              14
# 3                     36            46      3  ...              14
# 4                     36            46      4  ...              14
# 5                     36            46      5  ...              14
# ...                  ...           ...    ...  ...             ...
# 75751                 24            45  75751  ...              25
# 75752                 24            45  75752  ...              25
# 75753                 24            45  75753  ...              25
# 75754                 15            40  75754  ...               6
# 75756                 18            41  75756  ...              16
#
#        august_avg_temp  building_class  april_avg_temp  april_min_temp  \
# 1            62.161290      Commercial       55.500000              41
# 2            62.161290      Commercial       55.500000              41
# 3            62.161290      Commercial       55.500000              41
# 4            62.161290      Commercial       55.500000              41
# 5            62.161290      Commercial       55.500000              41
# ...                ...             ...             ...             ...
# 75751        68.612903     Residential       56.266667              40
# 75752        68.612903      Commercial       56.266667              40
# 75753        68.612903     Residential       56.266667              40
# 75754        61.612903      Commercial       50.183333              34
# 75756        64.338710     Residential       51.533333              36
#
#        july_min_temp  march_max_temp  april_max_temp  august_min_temp  \
# 1                 52              80              78               52
# 2                 52              80              78               52
# 3                 52              80              78               52
# 4                 52              80              78               52
# 5                 52              80              78               52
# ...              ...             ...             ...              ...
# 75751             54              71              89               52
# 75752             54              71              89               52
# 75753             54              71              89               52
# 75754             48              62              79               48
# 75756             48              66              85               49
#
#          site_eui
# 1       26.500150
# 2       24.693619
# 3       48.406926
# 4        3.899395
# 5        6.597715
# ...           ...
# 75751   70.298783
# 75752  132.918411
# 75753   39.483672
# 75754   48.404398
# 75756   29.154684
#
# [69409 rows x 59 columns]

# %% [markdown]
# ## Performing EDA

# %%
df2
# Out:
#        june_max_temp  heating_degree_days  days_above_100F  days_above_110F  \
# 1                 90                 2960                0                0
# 2                 90                 2960                0                0
# 3                 90                 2960                0                0
# 4                 90                 2960                0                0
# 5                 90                 2960                0                0
# ...              ...                  ...              ...              ...
# 75751             91                 3772                0                0
# 75752             91                 3772                0                0
# 75753             91                 3772                0                0
# 75754             86                 6218                0                0
# 75756             90                 5853                0                0
#
#        september_min_temp  cooling_degree_days  precipitation_inches  \
# 1                      52                  115                 16.59
# 2                      52                  115                 16.59
# 3                      52                  115                 16.59
# 4                      52                  115                 16.59
# 5                      52                  115                 16.59
# ...                   ...                  ...                   ...
# 75751                  44                  260                 45.03
# 75752                  44                  260                 45.03
# 75753                  44                  260                 45.03
# 75754                  41                   55                106.32
# 75756                  43                  148                107.69
#
#        december_min_temp  may_min_temp     id  ...  days_above_80F  \
# 1                     36            46      1  ...              14
# 2                     36            46      2  ...              14
# 3                     36            46      3  ...              14
# 4                     36            46      4  ...              14
# 5                     36            46      5  ...              14
# ...                  ...           ...    ...  ...             ...
# 75751                 24            45  75751  ...              25
# 75752                 24            45  75752  ...              25
# 75753                 24            45  75753  ...              25
# 75754                 15            40  75754  ...               6
# 75756                 18            41  75756  ...              16
#
#        august_avg_temp  building_class  april_avg_temp  april_min_temp  \
# 1            62.161290      Commercial       55.500000              41
# 2            62.161290      Commercial       55.500000              41
# 3            62.161290      Commercial       55.500000              41
# 4            62.161290      Commercial       55.500000              41
# 5            62.161290      Commercial       55.500000              41
# ...                ...             ...             ...             ...
# 75751        68.612903     Residential       56.266667              40
# 75752        68.612903      Commercial       56.266667              40
# 75753        68.612903     Residential       56.266667              40
# 75754        61.612903      Commercial       50.183333              34
# 75756        64.338710     Residential       51.533333              36
#
#        july_min_temp  march_max_temp  april_max_temp  august_min_temp  \
# 1                 52              80              78               52
# 2                 52              80              78               52
# 3                 52              80              78               52
# 4                 52              80              78               52
# 5                 52              80              78               52
# ...              ...             ...             ...              ...
# 75751             54              71              89               52
# 75752             54              71              89               52
# 75753             54              71              89               52
# 75754             48              62              79               48
# 75756             48              66              85               49
#
#          site_eui
# 1       26.500150
# 2       24.693619
# 3       48.406926
# 4        3.899395
# 5        6.597715
# ...           ...
# 75751   70.298783
# 75752  132.918411
# 75753   39.483672
# 75754   48.404398
# 75756   29.154684
#
# [69409 rows x 59 columns]

# %%
for col in getsmallercols(df2,15):
    sns.violinplot(data=df2,x=col,y='site_eui')
    plt.show()

# %%
target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d5a93703cc22> in <module>
# ----> 1 target
#
# NameError: name 'target' is not defined

# %%
# Out:
#        june_max_temp  heating_degree_days  days_above_100F  days_above_110F  \
# 1                 90                 2960                0                0
# 2                 90                 2960                0                0
# 3                 90                 2960                0                0
# 4                 90                 2960                0                0
# 5                 90                 2960                0                0
# ...              ...                  ...              ...              ...
# 75751             91                 3772                0                0
# 75752             91                 3772                0                0
# 75753             91                 3772                0                0
# 75754             86                 6218                0                0
# 75756             90                 5853                0                0
#
#        september_min_temp  cooling_degree_days  precipitation_inches  \
# 1                      52                  115                 16.59
# 2                      52                  115                 16.59
# 3                      52                  115                 16.59
# 4                      52                  115                 16.59
# 5                      52                  115                 16.59
# ...                   ...                  ...                   ...
# 75751                  44                  260                 45.03
# 75752                  44                  260                 45.03
# 75753                  44                  260                 45.03
# 75754                  41                   55                106.32
# 75756                  43                  148                107.69
#
#        december_min_temp  may_min_temp     id  ...  days_above_80F  \
# 1                     36            46      1  ...              14
# 2                     36            46      2  ...              14
# 3                     36            46      3  ...              14
# 4                     36            46      4  ...              14
# 5                     36            46      5  ...              14
# ...                  ...           ...    ...  ...             ...
# 75751                 24            45  75751  ...              25
# 75752                 24            45  75752  ...              25
# 75753                 24            45  75753  ...              25
# 75754                 15            40  75754  ...               6
# 75756                 18            41  75756  ...              16
#
#        august_avg_temp  building_class  april_avg_temp  april_min_temp  \
# 1            62.161290      Commercial       55.500000              41
# 2            62.161290      Commercial       55.500000              41
# 3            62.161290      Commercial       55.500000              41
# 4            62.161290      Commercial       55.500000              41
# 5            62.161290      Commercial       55.500000              41
# ...                ...             ...             ...             ...
# 75751        68.612903     Residential       56.266667              40
# 75752        68.612903      Commercial       56.266667              40
# 75753        68.612903     Residential       56.266667              40
# 75754        61.612903      Commercial       50.183333              34
# 75756        64.338710     Residential       51.533333              36
#
#        july_min_temp  march_max_temp  april_max_temp  august_min_temp  \
# 1                 52              80              78               52
# 2                 52              80              78               52
# 3                 52              80              78               52
# 4                 52              80              78               52
# 5                 52              80              78               52
# ...              ...             ...             ...              ...
# 75751             54              71              89               52
# 75752             54              71              89               52
# 75753             54              71              89               52
# 75754             48              62              79               48
# 75756             48              66              85               49
#
#          site_eui
# 1       26.500150
# 2       24.693619
# 3       48.406926
# 4        3.899395
# 5        6.597715
# ...           ...
# 75751   70.298783
# 75752  132.918411
# 75753   39.483672
# 75754   48.404398
# 75756   29.154684
#
# [69409 rows x 59 columns]
